# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\Data Analyst project\archive\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df[df['TotalCharges'].isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df.groupby('Contract')['Churn'].value_counts(normalize=True) * 100
# Out:
# Contract        Churn
# Month-to-month  No       57.290323
#                 Yes      42.709677
# One year        No       88.730482
#                 Yes      11.269518
# Two year        No       97.168142
#                 Yes       2.831858
# Name: proportion, dtype: float64

# %%
df.groupby('InternetService')['Churn'].value_counts(normalize=True) * 100
# Out:
# InternetService  Churn
# DSL              No       81.040892
#                  Yes      18.959108
# Fiber optic      No       58.107235
#                  Yes      41.892765
# No               No       92.595020
#                  Yes       7.404980
# Name: proportion, dtype: float64

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
findings = """
Overall churn rate: 26.54%

Churn rate by contract type:
- Month-to-month: 42.71%
- One year: 11.27%
- Two year: 2.83%

Churn rate by internet service:
- DSL: 18.96%
- Fiber optic: 41.89%
- No internet: 7.40%

Average monthly charges:
- Customers who stayed: ₹61.27
- Customers who churned: ₹74.44
"""

# %%
import sys
# !{sys.executable} -m pip install anthropic

# %%
api_key = "YOUR_API_KEY_HERE"

# %%
import sys
# !{sys.executable} -m pip install google-genai

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
   model="gemini-3.6-flash",
    contents=f"You are a business analyst. Based on these findings, write a short report with 3 key insights and 2 recommendations for the company:\n\n{findings}"
)

print(response.text)
# Out:
# # Customer Churn Analysis Report
#
# **Prepared by:** Business Analyst
# **Focus:** Customer Retention & Revenue Risk Mitigation
#
# ---
#
# ### **Executive Summary**
# The company currently faces a high overall customer churn rate of **26.54%**. Analysis reveals that customer attrition is heavily concentrated among month-to-month contract holders, premium Fiber Optic subscribers, and customers with higher average monthly bills.
#
# ---
#
# ### **3 Key Insights**
#
# 1. **Contract Duration Significantly Mitigates Churn:**
#    Month-to-month customers exhibit a critical churn rate of **42.71%**, making them nearly 15 times more likely to leave than customers on two-year contracts (**2.83%**). Short-term flexibility is currently the primary gateway for customer departure.
#
# 2. **Fiber Optic Service Holds the Highest Customer Flight Risk:**
# ...

# %%
import sys
# !{sys.executable} -m pip install mysql-connector-python sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/17.7 MB 5.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.1/17.7 MB 7.3 MB/s eta 0:00:03
#    ------- -------------------------------- 3.1/17.7 MB 7.0 MB/s eta 0:00:03
#    -------- ------------------------------- 3.7/17.7 MB 5.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 5.0/17.7 MB 5.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 7.1/17.7 MB 6.3 MB/s eta 0:00:02
#    ------------------ --------------------- 8.1/17.7 MB 6.0 MB/s eta 0:00:02
#    -------------------- ------------------- 8.9/17.7 MB 6.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 10.0/17.7 MB 5.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 10.5/17.7 MB 5.3 MB/s eta 0:00:02
#    ------------------------- -------------- 11.3/17.7 MB 5.1 MB/s eta 0:00:02
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:YOUR_PASSWORD@localhost/churn_project")

df.to_sql('customers', con=engine, if_exists='replace', index=False)

print("Data uploaded successfully!")
# Out:
# Data uploaded successfully!
